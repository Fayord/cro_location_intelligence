# %%
image_path = "/Users/user/Desktop/Screenshot 2023-12-21 at 1.27.07 PM.png"
from PIL import Image

image = Image.open(image_path)

# %%
import matplotlib.pyplot as plt


def show_image(image):
    plt.imshow(image)

    plt.show()
    # resize to 512 x 512


image = image.resize((512, 512))
image
show_image(image)

# %%
def rotate_image(image, angle):
    return image.rotate(angle)


def flip_image(image):
    return image.transpose(Image.FLIP_LEFT_RIGHT)


rotated_image = rotate_image(image, 45)
show_image(rotated_image)
fliped_image = flip_image(image)
show_image(fliped_image)
# Out:
# /var/folders/9g/3rr3k99j0td2974k71sy46_h0000gp/T/ipykernel_85804/3914997025.py:4: DeprecationWarning: FLIP_LEFT_RIGHT is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.FLIP_LEFT_RIGHT instead.
#   return image.transpose(Image.FLIP_LEFT_RIGHT)
